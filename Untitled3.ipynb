# %% [markdown]
# <a href="https://colab.research.google.com/github/CaiocSiqueira/CaiocSiqueira/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Leitura do Arquivo CSV

# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd

def read_csv_file(filename):
    data = []

    with open(filename, 'r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for row in csv_reader:
            data.append(row)

    return data

csv_filename = 'Gyroscope.csv'
csv_data = read_csv_file(csv_filename)

for row in csv_data:
      print(row)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# {'time': '1692462495366152400', 'seconds_elapsed': '46.24515234375', 'z': '1.291483759880066', 'y': '-0.3009186387062073', 'x': '-1.5999616384506226'}
# {'time': '1692462495375657700', 'seconds_elapsed': '46.25465771484375', 'z': '0.992168664932251', 'y': '-0.05291464552283287', 'x': '-1.6097352504730225'}
# {'time': '1692462495385163000', 'seconds_elapsed': '46.2641630859375', 'z': '0.6977402567863464', 'y': '0.1608818918466568', 'x': '-1.6188979148864746'}
# {'time': '1692462495394668300', 'seconds_elapsed': '46.27366821289063', 'z': '0.4546230733394623', 'y': '0.3294757306575775', 'x': '-1.5950748920440674'}
# {'time': '1692462495404173600', 'seconds_elapsed': '46.28317358398437', 'z': '0.30191126465797424', 'y': '0.4375956952571869', 'x': '-1.5321576595306396'}
# {'time': '1692462495413678800', 'seconds_elapsed': '46.292678955078124', 'z': '0.2286095917224884', 'y': '0.49440449476242065', 'x': '-1.4716837406158447'}
# ...

# %% [markdown]
# # Gráfico do giroscópio
# #### Movimentação no eixos x, y e z em função do tempo

# %%
from matplotlib.ticker import MultipleLocator

data = pd.read_csv('Gyroscope.csv')
data['time'] = pd.to_datetime(data['time'], unit='ns')

# Calculate time in seconds relative to the first timestamp
data['time_seconds'] = (data['time'] - data['time'].iloc[0]).dt.total_seconds()

plt.figure(figsize=(22, 12))

# Plot x, y, and z axes
plt.plot(data['time_seconds'], data['x'], label='x-axis', color='blue')
plt.plot(data['time_seconds'], data['y'], label='y-axis', color='green')
plt.plot(data['time_seconds'], data['z'], label='z-axis', color='red')

# Add labels and legend
plt.xlabel('Tempo (segundos)')
plt.ylabel('Deslocamento no espaço')
plt.title('Eixos ao longo do tempo')
plt.legend()

# Show grid
plt.grid(True)

# Set x-axis ticks with a 1-second interval
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))

# Set x-axis limits to start from 0
ax.set_xlim(0, data['time_seconds'].iloc[-1])

# Show the plot
plt.show()

# %% [markdown]
# # Gráfico do acelerometro
# #### Movimentação no eixos x, y e z em função do tempo

# %%
from matplotlib.ticker import MultipleLocator

data = pd.read_csv('Accelerometer.csv')
data['time'] = pd.to_datetime(data['time'], unit='ns')

# Calculate time in seconds relative to the first timestamp
data['time_seconds'] = (data['time'] - data['time'].iloc[0]).dt.total_seconds()

plt.figure(figsize=(22, 12))

# Plot x, y, and z axes
plt.plot(data['time_seconds'], data['x'], label='x-axis', color='blue')
plt.plot(data['time_seconds'], data['y'], label='y-axis', color='green')
plt.plot(data['time_seconds'], data['z'], label='z-axis', color='red')

# Add labels and legend
plt.xlabel('Tempo (segundos)')
plt.ylabel('Deslocamento no espaço')
plt.title('Eixos ao longo do tempo')
plt.legend()

# Show grid
plt.grid(True)

# Set x-axis ticks with a 1-second interval
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))

# Set x-axis limits to start from 0
ax.set_xlim(0, data['time_seconds'].iloc[-1])

# Show the plot
plt.show()

# %% [markdown]
# # Gráfico do Magnetometro
# #### Movimentação no eixos x, y e z em função do tempo

# %%
from matplotlib.ticker import MultipleLocator

data = pd.read_csv('Magnetometer.csv')
data['time'] = pd.to_datetime(data['time'], unit='ns')

# Calculate time in seconds relative to the first timestamp
data['time_seconds'] = (data['time'] - data['time'].iloc[0]).dt.total_seconds()

plt.figure(figsize=(22, 12))

# Plot x, y, and z axes
plt.plot(data['time_seconds'], data['x'], label='x-axis', color='blue')
plt.plot(data['time_seconds'], data['y'], label='y-axis', color='green')
plt.plot(data['time_seconds'], data['z'], label='z-axis', color='red')

# Add labels and legend
plt.xlabel('Tempo (segundos)')
plt.ylabel('Deslocamento no espaço')
plt.title('Eixos ao longo do tempo')
plt.legend()

# Show grid
plt.grid(True)

# Set x-axis ticks with a 1-second interval
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))

# Set x-axis limits to start from 0
ax.set_xlim(0, data['time_seconds'].iloc[-1])

# Show the plot
plt.show()

# %% [markdown]
# # Gráfico do Giroscopio com movimentos involuntários

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MultipleLocator

data = pd.read_csv('/content/sample_data/Gyroscope2.csv')
data['time'] = pd.to_datetime(data['time'], unit='ns')

# Calculate time in seconds relative to the first timestamp
data['time_seconds'] = (data['time'] - data['time'].iloc[0]).dt.total_seconds()

plt.figure(figsize=(22, 12))

# Plot x, y, and z axes
plt.plot(data['time_seconds'], data['x'], label='x-axis', color='blue')
plt.plot(data['time_seconds'], data['y'], label='y-axis', color='green')
plt.plot(data['time_seconds'], data['z'], label='z-axis', color='red')

# Add labels and legend
plt.xlabel('Tempo (segundos)')
plt.ylabel('Deslocamento no espaço')
plt.title('Eixos ao longo do tempo')
plt.legend()

# Show grid
plt.grid(True)

# Set x-axis ticks with a 1-second interval
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))

# Set x-axis limits to start from 0
ax.set_xlim(0, data['time_seconds'].iloc[-1])

# Show the plot
plt.show()

# %% [markdown]
# #Gráfico do Acelerometro com movimentos involuntários

# %%
from matplotlib.ticker import MultipleLocator

data = pd.read_csv('/content/Accelerometer2.csv')
data['time'] = pd.to_datetime(data['time'], unit='ns')

# Calculate time in seconds relative to the first timestamp
data['time_seconds'] = (data['time'] - data['time'].iloc[0]).dt.total_seconds()

plt.figure(figsize=(22, 12))

# Plot x, y, and z axes
plt.plot(data['time_seconds'], data['x'], label='x-axis', color='blue')
plt.plot(data['time_seconds'], data['y'], label='y-axis', color='green')
plt.plot(data['time_seconds'], data['z'], label='z-axis', color='red')

# Add labels and legend
plt.xlabel('Tempo (segundos)')
plt.ylabel('Deslocamento no espaço')
plt.title('Eixos ao longo do tempo')
plt.legend()

# Show grid
plt.grid(True)

# Set x-axis ticks with a 1-second interval
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))

# Set x-axis limits to start from 0
ax.set_xlim(0, data['time_seconds'].iloc[-1])

# Show the plot
plt.show()

# %% [markdown]
# # Gráfico do Magnetometro com movimentos involuntários

# %%
from matplotlib.ticker import MultipleLocator

data = pd.read_csv('/content/Magnetometer2.csv')
data['time'] = pd.to_datetime(data['time'], unit='ns')

# Calculate time in seconds relative to the first timestamp
data['time_seconds'] = (data['time'] - data['time'].iloc[0]).dt.total_seconds()

plt.figure(figsize=(22, 12))

# Plot x, y, and z axes
plt.plot(data['time_seconds'], data['x'], label='x-axis', color='blue')
plt.plot(data['time_seconds'], data['y'], label='y-axis', color='green')
plt.plot(data['time_seconds'], data['z'], label='z-axis', color='red')

# Add labels and legend
plt.xlabel('Tempo (segundos)')
plt.ylabel('Deslocamento no espaço')
plt.title('Eixos ao longo do tempo')
plt.legend()

# Show grid
plt.grid(True)

# Set x-axis ticks with a 1-second interval
ax = plt.gca()
ax.xaxis.set_major_locator(MultipleLocator(1))

# Set x-axis limits to start from 0
ax.set_xlim(0, data['time_seconds'].iloc[-1])

# Show the plot
plt.show()
